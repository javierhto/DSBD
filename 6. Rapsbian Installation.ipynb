# %% [markdown]
# # Rapsbian Installation

# %%
from IPython.display import Image
Image("https://upload.wikimedia.org/wikipedia/commons/thumb/d/d1/Raspberry_Pi_OS_Logo.png/800px-Raspberry_Pi_OS_Logo.png")

# %% [markdown]
# ## 1. Installation of VirtualBox

# %% [markdown]
# Raspberry Pi OS is a free operating system based on Debian, optimised for the Raspberry Pi hardware, and is the recommended operating system for normal use on a Raspberry Pi. The OS comes with over 35,000 packages: precompiled software bundled in a nice format for easy installation on your Raspberry Pi.

# %%
Image("https://www.virtualbox.org/graphics/vbox_logo2_gradient.png")

# %% [markdown]
# VirtualBox is a powerful x86 and AMD64/Intel64 virtualization product for enterprise as well as home use. VirtualBox is a general-purpose full virtualizer for x86 hardware, targeted at server, desktop and embedded use. Not only is VirtualBox an extremely feature rich, high performance product for enterprise customers, it is also the only professional solution that is freely available as Open Source Software under the terms of the GNU General Public License (GPL) version 2.

# %% [markdown]
# ## Download Links

# %% [markdown]
# *[Windows][1]
# *[Linux][2]
# *[OS X][3]
#
# [1]: https://download.virtualbox.org/virtualbox/6.1.32/VirtualBox-6.1.32-149290-Win.exe
# [2]: https://www.virtualbox.org/wiki/Linux_Downloads
# [3]: https://download.virtualbox.org/virtualbox/6.1.32/VirtualBox-6.1.32-149290-OSX.dmg
